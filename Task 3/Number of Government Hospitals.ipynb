# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('D://Internship/450071')

# %%
df
# Out:
#                    States/UTs Rural hospitals Unnamed: 2 Urban hospitals  \
# 0                         NaN             No.       Beds             No.
# 1              Andhra Pradesh             193       6480              65
# 2          Arunachal Pradesh*             208       2136              10
# 3                       Assam            1176      10944              50
# 4                       Bihar             930       6083             103
# 5                Chhattisgarh             169       5070              45
# 6                        Goa*              17       1405              25
# 7                     Gujarat             364      11715             122
# 8                    Haryana*             609       6690              59
# 9           Himachal Pradesh*             705       5665              96
# 10            Jammu & Kashmir              56       7234              76
# 11                  Jharkhand             519       5842              36
# ...

# %%
#df['state'].iloc[4]

# %%
#pd.read_csv('D://Internship/450072')

# %%
df = df.rename(columns={'Unnamed: 2':'Rural_Beds','Unnamed: 4':'Urban_Beds','state':'State Population'})

# %%
df.drop(index=[0,37],inplace=True)

# %%
df.isnull().sum()
# Out:
# States/UTs          0
# Rural hospitals     0
# Rural_Beds          0
# Urban hospitals     0
# Urban_Beds          0
# As on               0
# State Population    0
# dtype: int64

# %%
df.describe()
# Out:
#        State Population
# count      3.600000e+01
# mean       3.359945e+07
# std        4.227817e+07
# min        6.447300e+04
# 25%        1.439840e+06
# 50%        2.106970e+07
# 75%        6.060359e+07
# max        1.998123e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 1 to 36
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   States/UTs        36 non-null     object
#  1   Rural hospitals   36 non-null     object
#  2   Rural_Beds        36 non-null     object
#  3   Urban hospitals   36 non-null     object
#  4   Urban_Beds        36 non-null     object
#  5   As on             36 non-null     object
#  6   State Population  36 non-null     float64
# dtypes: float64(1), object(6)
# memory usage: 2.2+ KB

# %%
df['Rural hospitals'] = df['Rural hospitals'].apply(int)

# %%
df['Rural_Beds'] = df['Rural_Beds'].apply(int)

# %%
df['Urban hospitals'] = df['Urban hospitals'].apply(int)

# %%
df['Urban_Beds'] = df['Urban_Beds'].apply(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 1 to 36
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   States/UTs        36 non-null     object
#  1   Rural hospitals   36 non-null     int64
#  2   Rural_Beds        36 non-null     int64
#  3   Urban hospitals   36 non-null     int64
#  4   Urban_Beds        36 non-null     int64
#  5   As on             36 non-null     object
#  6   State Population  36 non-null     float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 2.2+ KB

# %%
#df.sort_values('State Population')

# %%
def year(df):
    sampl = df.split('.')
    yr = sampl[-1]
    return int(yr)

# %%
df['Year'] = df['As on'].apply(year)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 1 to 36
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   States/UTs        36 non-null     object
#  1   Rural hospitals   36 non-null     int64
#  2   Rural_Beds        36 non-null     int64
#  3   Urban hospitals   36 non-null     int64
#  4   Urban_Beds        36 non-null     int64
#  5   As on             36 non-null     object
#  6   State Population  36 non-null     float64
#  7   Year              36 non-null     int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ KB

# %%
df.head()
# Out:
#            States/UTs  Rural hospitals  Rural_Beds  Urban hospitals  \
# 1      Andhra Pradesh              193        6480               65
# 2  Arunachal Pradesh*              208        2136               10
# 3               Assam             1176       10944               50
# 4               Bihar              930        6083              103
# 5        Chhattisgarh              169        5070               45
#
#    Urban_Beds       As on  State Population  Year
# 1       16658  01.01.2017        84580777.0  2017
# 2         268  31.12.2017         1383727.0  2017
# 3        6198  31.12.2017        31205576.0  2017
# 4        5936  31.12.2016       104099452.0  2016
# 5        4342  01.01.2016        25545198.0  2016

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(data=df,x=df.sort_values('State Population')['States/UTs'],y='State Population')
plt.xticks(rotation=90);
print('This graph display each State and Union territories population')
# Out:
# This graph display each State and Union territories population

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(data=df,x=df.sort_values('State Population')['States/UTs'],y='Urban hospitals')
plt.xticks(rotation=90);
print('Below graph represent urban hospitals of each states and union territories.')
# Out:
# Below graph represent urban hospitals of each states and union territories.

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(data=df,x=df.sort_values('State Population')['States/UTs'],y='Rural hospitals')
plt.xticks(rotation=90);
print('Below graph represent rural hospitals of each states and union territories.')
# Out:
# Below graph represent rural hospitals of each states and union territories.

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(data=df,x=df.sort_values('State Population')['States/UTs'],y='Urban_Beds')
plt.xticks(rotation=90);
print('Below graph represent number of beds in urban hospitals of each states and union territories.')
# Out:
# Below graph represent number of beds in urban hospitals of each states and union territories.

# %%
plt.figure(figsize=(12,6),dpi=100)
sns.barplot(data=df,x=df.sort_values('State Population')['States/UTs'],y='Rural_Beds')
plt.xticks(rotation=90);
print('Below graph represent number of beds in rural hospitals of each states and union territories.')
# Out:
# Below graph represent number of beds in rural hospitals of each states and union territories.

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(data=df, x='Urban hospitals', y='Urban_Beds')
# Out:
# <AxesSubplot:xlabel='Urban hospitals', ylabel='Urban_Beds'>

# %%
sns.scatterplot(data=df, x='Rural hospitals', y='Rural_Beds')
# Out:
# <AxesSubplot:xlabel='Rural hospitals', ylabel='Rural_Beds'>

# %% [markdown]
# Arranging dataset according to population of states and union territories

# %%
df2 = df

# %%
df2 = df2.sort_values('State Population')

# %%
df2 = df2.reset_index()

# %%
df2 = df2.drop('index',axis=1)

# %%
df2
# Out:
#                    States/UTs  Rural hospitals  Rural_Beds  Urban hospitals  \
# 0                 Lakshadweep                9         300                0
# 1                 Daman & Diu                5         240                0
# 2       Dadra & Nagar Haveli*               10         273                1
# 3   Andaman & Nicobar Islands               27         575                3
# 4                     Sikkim*               24         260                9
# 5                  Chandigarh                0           0                4
# 6                    Mizoram*               56         604               34
# 7                  Puducherry                3          96               11
# 8          Arunachal Pradesh*              208        2136               10
# 9                        Goa*               17        1405               25
# 10                   Nagaland               21         630               15
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df2,x=df2['States/UTs'],y='Urban_Beds')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df2,x=df2['States/UTs'],y='Rural_Beds')
plt.xticks(rotation=90);

# %% [markdown]
# # Comparing Urban and Rural hospitals

# %%
plt.figure(figsize=(10,10))
plt.bar(df2['States/UTs'],df2['Urban_Beds'],label='Urban Beds',align='edge',alpha=0.6)
plt.bar(df2['States/UTs'],df2['Urban hospitals'],label='Urban hospitals',align='edge')



plt.legend()
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,10))
plt.bar(df2['States/UTs'],df2['Rural_Beds'],label='Rural Beds',align='edge',alpha=0.6)
plt.bar(df2['States/UTs'],df2['Rural hospitals'],label='Rural hospitals',align='edge')



plt.legend()
plt.xticks(rotation=90);

# %% [markdown]
# # Comparing Urban and Rural hospitals beds

# %%
plt.figure(figsize=(10,10))
plt.bar(df2['States/UTs'],df2['Rural hospitals'],label='Rural hospitals',align='edge',alpha=0.6)
plt.bar(df2['States/UTs'],df2['Urban hospitals'],label='Urban hospitals',align='edge',alpha=0.6)


plt.legend()
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,10))
plt.bar(df2['States/UTs'],df2['Urban_Beds'],label='Urban Beds',align='edge')
plt.bar(df2['States/UTs'],df2['Rural_Beds'],label='Rural Beds',align='edge',alpha=0.6)

plt.legend()
plt.xticks(rotation=90);
